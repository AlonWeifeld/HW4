# %%
#Alon Weisfeld
#308353994

import json
import requests
import pandas as pd

# %%
dests = open(r'D:\Alon\DATA_STUDY\HW\HW4\dests.txt')
citys = []
for i in dests:
    i = i.rstrip()
    citys.append(i)
print(citys)
# Out:
# ['Istanbul', 'Amsterdam', 'Valletta', 'Basel', 'Doha']

# %%
url=[]
urlgeo=[]
for destinations in citys:
    urlgeo.append("https://maps.googleapis.com/maps/api/geocode/json?address=%s&key=%s"%(destinations,Api_key))
    url.append("https://maps.googleapis.com/maps/api/distancematrix/json?origins=Jerusalem&destinations=%s&key=AIzaSyBexgg42p-uUe-wzN-iACHS7NnYBOddIO8"%(destinations,Api_key))
print(urlgeo)
# Out:
# ['https://maps.googleapis.com/maps/api/geocode/json?address=Istanbul&key=AIzaSyBexgg42p-uUe-wzN-iACHS7NnYBOddIO8', 'https://maps.googleapis.com/maps/api/geocode/json?address=Amsterdam&key=AIzaSyBexgg42p-uUe-wzN-iACHS7NnYBOddIO8', 'https://maps.googleapis.com/maps/api/geocode/json?address=Valletta&key=AIzaSyBexgg42p-uUe-wzN-iACHS7NnYBOddIO8', 'https://maps.googleapis.com/maps/api/geocode/json?address=Basel&key=AIzaSyBexgg42p-uUe-wzN-iACHS7NnYBOddIO8', 'https://maps.googleapis.com/maps/api/geocode/json?address=Doha&key=AIzaSyBexgg42p-uUe-wzN-iACHS7NnYBOddIO8']

# %%
distances=[]
for i in url:
    distances.append(requests.get(i).json())  

addresses=[]
for i in urlgeo:
    addresses.append(requests.get(i).json())
    
dic = {}
for i in range(5):
    dic[i] = (distances[i]['rows'][0]['elements'][0]['distance']['text'],
    distances[i]['rows'][0]['elements'][0]['duration']['text'],addresses[i]['results'][0]['geometry']['location']['lng'],
    addresses[i]['results'][0]['geometry']['location']['lat']  )   
    dic[citys[i]] = dic.pop(i)
print(dic)
# Out:
# {'Istanbul': ('1,809 km', '20 hours 42 mins', 28.9783589, 41.0082376), 'Amsterdam': ('4,530 km', '2 days 0 hours', 4.9041389, 52.3675734), 'Valletta': ('3,783 km', '2 days 2 hours', 14.5145528, 35.8989085), 'Basel': ('4,091 km', '1 day 20 hours', 7.5885761, 47.5595986), 'Doha': ('2,104 km', '21 hours 51 mins', 51.53103979999999, 25.2854473)}

# %%
for i in citys:
    print(i ,'\ndistance : ', dic[i][0] , '\nduration : ', dic[i][1], '\nLongitude : ', dic[i][2], '\nLatitude : ', dic[i][3], '\n')
# Out:
# Istanbul
# distance :  1,809 km
# duration :  20 hours 42 mins
# Longitude :  28.9783589
# Latitude :  41.0082376
#
# Amsterdam
# distance :  4,530 km
# duration :  2 days 0 hours
# Longitude :  4.9041389
# Latitude :  52.3675734
#
# Valletta
# distance :  3,783 km
# duration :  2 days 2 hours
# Longitude :  14.5145528
# Latitude :  35.8989085
#
# Basel
# distance :  4,091 km
# duration :  1 day 20 hours
# Longitude :  7.5885761
# Latitude :  47.5595986
#
# Doha
# distance :  2,104 km
# duration :  21 hours 51 mins
# Longitude :  51.53103979999999
# Latitude :  25.2854473

# %%
array = []
for i in citys:
    dis = dic[i][0].split()
    array.append(int(dis[0].replace(',','')))

dic_far = []
for i in range(3):
    dic_far.append(max(array)) 
    array.remove(max(array))

array = []
for i in citys:
    dis = dic[i][0].split()
    array.append(int(dis[0].replace(',','')))

far_city = []
for i in range(3):
    for j in range(len(array)):
        if dic_far[i] == array[j]:
            far_city.append(citys[j])
print('The three farthest cities are : ', far_city)
# Out:
# The three farthest cities are :  ['Amsterdam', 'Basel', 'Valletta']
